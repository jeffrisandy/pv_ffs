# %%
# !pip install git+https://github.com/jeffrisandy/pv_ffs.git

# %% [markdown]
# ## V1.1 Changes log
# 1. FIX head calculation t-Req and MAWP
# 2. CHANGE CML input data to accept multiple CMLs of head or shell instead of 1 CML per section
# 3. ADD head area : knuckle or center. Adopt API 510 7.4.2 Corroded Areas in Vessel Heads: for ellips head, use hemis head formula for center area and use ellips head for knuckle area

# %%
# import Module , don't delete!

from FFS import *
"""
DATA INPUT
"""
###############
# STATIC DATA #
###############

DATA = {
    'NAME': "AWT Separator B",
    'EQ_NO': "DRI-V-01020",
    'TAG_NO' : "8124.V.0701.B",
    'AREA' : "AWT 12 S",
    'SERIAL_NO' : "SBS-00807",
    'YEAR_BUILT' : 2008,
    'PV_ORIENTATION' : "Vertical", # vertical or horizaontal
    'MATERIAL' : "SA 516 Gr. 70",

    # dimension
    'OD' : 72, # inch, Outside Dia
    'L' : 113, # inch length / height of vessel

    # DESIGN DATA
    'DP' : 100, # psig, design pressure
    'DT' : 400, # F, design temp
    'CA' : 0.125, # inch, Corrosion Allowance
    'RT' : "SPOT",     # RT during design: FULL, PARTIAL
    

    # SHELL DATA
    'S_SHELL' : 20000, # SA 516 Gr 70
    'E_SHELL' : 0.85,
    'T_NOM_SHELL' : 0.3937, # inch

    # HEAD DATA
    'HEAD_TYPE' : "Ellipsoidal", # Ellipsoidal, Hemispherical, Torispherical, Flat
    'S_HEAD' : 20000, # SA 516 Gr 70
    'E_HEAD' : 1, # seamless head
    'T_NOM_HEAD' : 0.5, # inch,

    # factor K for ellipsoidal head 2:1
    'K' : 1,

    ###################
    # INSPECTION DATA #
    ###################
    # most inspection data is in milimeters unit

    ### INSPECTION INTERVAL ###
    'INTERVAL': 4, # YEARS AS PER CERTIFICATION

    ### INSPECTION DATE  ### 
    'insp_date_now' : "6/08/2019", # 7 Jan 2020
    'insp_date_prev' : "22/09/2016", # date/month/year  7 Jan 2017, type None if not availble

    ### SHELL ###
    't_nom_shell' : 10, # mm, nominal shell thick
    'shell_name': ['S1A', 'S1B', 'S2A', 'S2B', 'S3A', 'S3B', 'S4A', 'S4B'], # CML name
    't_now_shell': [8.72, 8.51, 8.76, 8.69, 8.61, 8.62, 8.866, 8.6 ], # in mm
    't_prev_shell': [9.35, 8.72, 9.56, 9.5, 9.02, 9.11, 9.16, 9 ], # in mm
    
    ### HEAD ###
    't_nom_head' : 12.8 , # mm, suggest to use max value of current inspection if actual thick > nominal thick
    'head1_name' : "TOP HEAD", # TOP / LEFT HEAD
    'head2_name' : "BOTTOM HEAD", # BOTTOM / RIGHT HEAD
 
    
    ### HEAD 1 : TOP OR LEFT HEAD ###
    'head_cml_name1': ['TH'], # CML name
    'head_area1' : ['knuckle'], # define head CML area in gead : knuckle or center
    't_now_head1': [ 10.81], # in mm
    't_prev_head1': [11.09], # in mm

    ### HEAD 2 : BOTTOM OR RIGHT HEAD ###
    'head_cml_name2': ['BH-A', 'BH-B'], # CML name
    'head_area2': ['knuckle', 'center'], # define head CML area in gead : knuckle or center
    't_now_head2': [ 11.56, 11.31],
    't_prev_head2': [11.76, 11.81],
    
    ### NOZZLES ###
    'S_NOZZLE' : 17100, # psi
    'E_NOZZLE' : 1, # seamless 
    'nozzles_name' : [ "N2", "N3", "N8", "MH"],
    'nozzles_size' : [ 6, 3, 3, 24 ], # NPS in inch

    # inch, height of nozzle location measured from top
    'nozzles_height': [10, 10, 90, 333], 

    # mm, nominal thick, mostly fabricated from shell plate,  
    # https://www.engineeringtoolbox.com/nominal-wall-thickness-pipe-d_1337.html
    'nozzles_thick_nom' : [11.31, 11.31, 11.38, 9.8], 

    # mm, min thick current inspection
    'nozzles_thick_now' : [11.11, 11.07, 11.32, 9.13], 

    # mm, min thick previous inspection or type None if not available e.q [None, None, None, None]
    'nozzles_thick_prev' : [10.2, 10.93, 10.98, 9.52] 
}

# %%
DATA
# Out:
# {'NAME': 'AWT Separator B',
#  'EQ_NO': 'DRI-V-01020',
#  'TAG_NO': '8124.V.0701.B',
#  'AREA': 'AWT 12 A',
#  'SERIAL_NO': 'SBS-00807',
#  'YEAR_BUILT': 2008,
#  'PV_ORIENTATION': 'Vertical',
#  'MATERIAL': 'SA 516 Gr. 70',
#  'OD': 72,
#  'L': 113,
#  'DP': 100,
#  'DT': 400,
#  'CA': 0.125,
#  'RT': 'SPOT',
#  'S_SHELL': 20000,
#  'E_SHELL': 0.85,
#  'T_NOM_SHELL': 0.3937,
#  'HEAD_TYPE': 'Ellipsoidal',
#  'S_HEAD': 20000,
#  'E_HEAD': 1,
#  'T_NOM_HEAD': 0.5,
#  'K': 1,
#  'INTERVAL': 4,
#  'insp_date_now': '6/08/2019',
#  'insp_date_prev': '22/09/2016',
#  't_nom_shell': 10,
#  'shell_name': ['S1A', 'S1B', 'S2A', 'S2B', 'S3A', 'S3B', 'S4A', 'S4B'],
#  't_now_shell': [8.72, 8.51, 8.76, 8.69, 8.61, 8.62, 8.866, 8.6],
#  't_prev_shell': [9.35, 8.72, 9.56, 9.5, 9.02, 9.11, 9.16, 9],
#  't_nom_head': 12.8,
#  'head1_name': 'TOP HEAD',
#  'head2_name': 'BOTTOM HEAD',
#  'head_cml_name1': ['TH'],
#  'head_area1': ['knuckle'],
#  't_now_head1': [10.81],
#  't_prev_head1': [11.09],
#  'head_cml_name2': ['BH-A', 'BH-B'],
#  'head_area2': ['knuckle', 'center'],
#  't_now_head2': [11.56, 11.31],
#  't_prev_head2': [11.76, 11.81],
#  'S_NOZZLE': 17100,
#  'E_NOZZLE': 1,
#  'nozzles_name': ['N2', 'N3', 'N8', 'MH'],
#  'nozzles_size': [6, 3, 3, 24],
#  'nozzles_height': [10, 10, 90, 333],
#  'nozzles_thick_nom': [11.31, 11.31, 11.38, 9.8],
#  'nozzles_thick_now': [11.11, 11.07, 11.32, 9.13],
#  'nozzles_thick_prev': [10.2, 10.93, 10.98, 9.52]}

# %%
ffs = FFS(DATA)
ffs.summary()
# Out:
#     =======================
#     DATA CONSTRUCTION NOTES
#     =======================
#
#     ====================
#     INTEGRITY EVALUATION
#     ====================
#
#     NAME            = AWT Separator B
#     EQ NO           = DRI-V-01020
#     TAG NO          = 8124.V.0701.B
#     AREA            = AWT 12 A
#     ORIENTATION     = Vertical
#     HEAD TYPE       = Ellipsoidal
#     OUTSIDE DIA     = 72 inch
#     LENGTH          = 113 inch
#     DESIGN PRESSURE = 100 psig
#     DESIGN TEMP     = 400 F
#     MATERIAL        = SA 516 Gr. 70
#     RT              = SPOT
#     YEAR BUILT      = 2008
#     INSPECTION DATE = 6/08/2019
#
#     == EVALUATION SUMMARY ==
#
#         Section   CML      RL     MAWP  is_Fit?
# 0          SHEL   S1A   15.28   129.57     True
# 1          SHEL   S1B   23.20   138.13     True
# 2          SHEL   S2A   12.18   121.53     True
# 3          SHEL   S2B   11.78   119.71     True
# 4          SHEL   S3A   22.70   138.89     True
# 5          SHEL   S3B   19.06   134.95     True
# 6          SHEL   S4A   33.95   149.55     True
# 7          SHEL   S4B   23.20   139.22     True
# 8      TOP HEAD    TH   34.60   206.69     True
# 9   BOTTOM HEAD  BH-A   60.55   231.52     True
# 10  BOTTOM HEAD  BH-B   50.34   433.51     True
# 11      NOZZLES    N2  100.00  2460.51     True
# 12      NOZZLES    N3  100.00  4890.14     True
# 13      NOZZLES    N8  100.00  5060.87     True
# 14      NOZZLES    MH   48.49   451.22     True
#
#     ----------------
#     SECTION - SHELL
#     ----------------
#
#     -------------
#     SHELL - S1A
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1164 mm/year
#       - Short Term Corrosion Rate = 0.2195 mm/year
#       - Selected Corrosion Rate is 0.2195 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.72 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 15.28 years.
#       - MAWP @next inspection at interval 4 years = 129.57 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S1A of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 129.57 psig which is larger than the design pressure (100 psig).
#       The remaining life is 15.28 years which is due in 16-Nov-2034.
#
#
#     -------------
#     SHELL - S1B
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1355 mm/year
#       - Short Term Corrosion Rate = 0.0732 mm/year
#       - Selected Corrosion Rate is 0.1355 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.51 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 23.2 years.
#       - MAWP @next inspection at interval 4 years = 138.13 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S1B of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 138.13 psig which is larger than the design pressure (100 psig).
#       The remaining life is 23.2 years which is due in 17-Oct-2042.
#
#
#     -------------
#     SHELL - S2A
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1127 mm/year
#       - Short Term Corrosion Rate = 0.2787 mm/year
#       - Selected Corrosion Rate is 0.2787 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.76 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 12.18 years.
#       - MAWP @next inspection at interval 4 years = 121.53 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S2A of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 121.53 psig which is larger than the design pressure (100 psig).
#       The remaining life is 12.18 years which is due in 10-Oct-2031.
#
#
#     -------------
#     SHELL - S2B
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1191 mm/year
#       - Short Term Corrosion Rate = 0.2822 mm/year
#       - Selected Corrosion Rate is 0.2822 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.69 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 11.78 years.
#       - MAWP @next inspection at interval 4 years = 119.71 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S2B of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 119.71 psig which is larger than the design pressure (100 psig).
#       The remaining life is 11.78 years which is due in 17-May-2031.
#
#
#     -------------
#     SHELL - S3A
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1264 mm/year
#       - Short Term Corrosion Rate = 0.1429 mm/year
#       - Selected Corrosion Rate is 0.1429 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.61 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 22.7 years.
#       - MAWP @next inspection at interval 4 years = 138.89 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S3A of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 138.89 psig which is larger than the design pressure (100 psig).
#       The remaining life is 22.7 years which is due in 18-Apr-2042.
#
#
#     -------------
#     SHELL - S3B
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1255 mm/year
#       - Short Term Corrosion Rate = 0.1707 mm/year
#       - Selected Corrosion Rate is 0.1707 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.62 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 19.06 years.
#       - MAWP @next inspection at interval 4 years = 134.95 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S3B of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 134.95 psig which is larger than the design pressure (100 psig).
#       The remaining life is 19.06 years which is due in 27-Aug-2038.
#
#
#     -------------
#     SHELL - S4A
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1031 mm/year
#       - Short Term Corrosion Rate = 0.1024 mm/year
#       - Selected Corrosion Rate is 0.1031 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.866 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 33.95 years.
#       - MAWP @next inspection at interval 4 years = 149.55 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S4A of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 149.55 psig which is larger than the design pressure (100 psig).
#       The remaining life is 33.95 years which is due in 18-Jul-2053.
#
#
#     -------------
#     SHELL - S4B
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1273 mm/year
#       - Short Term Corrosion Rate = 0.1394 mm/year
#       - Selected Corrosion Rate is 0.1394 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.6 mm.
#       - Thickness Required = 5.3662 mm.
#
#       *Integrity*
#       - Remaining life = 23.2 years.
#       - MAWP @next inspection at interval 4 years = 139.22 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The SHEL - S4B of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 139.22 psig which is larger than the design pressure (100 psig).
#       The remaining life is 23.2 years which is due in 17-Oct-2042.
#
#
#     --------------------------
#     SECTION - HEAD 1 TOP HEAD
#     --------------------------
#
#     -------------
#     HEAD 1 - TOP HEAD - TH
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1809 mm/year
#       - Short Term Corrosion Rate = 0.0976 mm/year
#       - Selected Corrosion Rate is 0.1809 mm/year
#
#       *Thickness*
#       - Thickness actual = 10.81 mm.
#       - Thickness Required = 4.5515 mm.
#
#       *Integrity*
#       - Remaining life = 34.6 years.
#       - MAWP @next inspection at interval 4 years = 206.69 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The TOP HEAD - TH of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 206.69 psig which is larger than the design pressure (100 psig).
#       The remaining life is 34.6 years which is due in 12-Mar-2054.
#
#
#     ------------------------------
#     SECTION - HEAD 2 BOTTOM HEAD
#     ------------------------------
#
#     -------------
#     HEAD 2 - BOTTOM HEAD - BH-A
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1127 mm/year
#       - Short Term Corrosion Rate = 0.0697 mm/year
#       - Selected Corrosion Rate is 0.1127 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.56 mm.
#       - Thickness Required = 4.7362 mm.
#
#       *Integrity*
#       - Remaining life = 60.55 years.
#       - MAWP @next inspection at interval 4 years = 231.52 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The BOTTOM HEAD - BH-A of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 231.52 psig which is larger than the design pressure (104.0757857 psig).
#       The remaining life is 60.55 years which is due in 22-Feb-2080.
#
#
#     -------------
#     HEAD 2 - BOTTOM HEAD - BH-B
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.1355 mm/year
#       - Short Term Corrosion Rate = 0.1742 mm/year
#       - Selected Corrosion Rate is 0.1742 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.31 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 50.34 years.
#       - MAWP @next inspection at interval 4 years = 433.51 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The BOTTOM HEAD - BH-B of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 433.51 psig which is larger than the design pressure (104.0757857 psig).
#       The remaining life is 50.34 years which is due in 07-Dec-2069.
#
#
#     -------------
#     NOZZLE 2 - N2
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0182 mm/year
#       - Short Term Corrosion Rate = 1e-05 mm/year
#       - Selected Corrosion Rate is 0.0182 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.11 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 2460.51 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The NOZZLES - N2 of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 2460.51 psig which is larger than the design pressure (100 psig).
#       The remaining life is 100 years which is due in 07-Aug-2119.
#
#
#     -------------
#     NOZZLE 2 - N3
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0218 mm/year
#       - Short Term Corrosion Rate = 1e-05 mm/year
#       - Selected Corrosion Rate is 0.0218 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.07 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 4890.14 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The NOZZLES - N3 of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 4890.14 psig which is larger than the design pressure (100 psig).
#       The remaining life is 100 years which is due in 07-Aug-2119.
#
#
#     -------------
#     NOZZLE 2 - N8
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0055 mm/year
#       - Short Term Corrosion Rate = 1e-05 mm/year
#       - Selected Corrosion Rate is 0.0055 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.32 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 5060.87 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The NOZZLES - N8 of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 5060.87 psig which is larger than the design pressure (100 psig).
#       The remaining life is 100 years which is due in 07-Aug-2119.
#
#
#     -------------
#     NOZZLE 2 - MH
#     -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0609 mm/year
#       - Short Term Corrosion Rate = 0.1359 mm/year
#       - Selected Corrosion Rate is 0.1359 mm/year
#
#       *Thickness*
#       - Thickness actual = 9.13 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 48.49 years.
#       - MAWP @next inspection at interval 4 years = 451.22 psig.
#       - Part anomaly status = GREEN
#
#       *Conclusion*
#
#       The NOZZLES - MH of the Vessel is fit for service within 4 years interval at the next inspection date in 06-Aug-2023.
#       The MAWP is 451.22 psig which is larger than the design pressure (100 psig).
#       The remaining life is 48.49 years which is due in 31-Jan-2068.
