# %%
# !pip install git+https://github.com/jeffrisandy/pv_ffs.git

# %%
# import Module , don't delete!
from FFS import *

"""
DATA INPUT
"""
###############
# STATIC DATA #
###############

DATA = {
  'NAME': "Gauging Separator B",
  'TAG_NO' : "6105-E-580-22-01 / 353SW-ZV-01C",
  'AREA' : "AWT 4 SW",
  'SERIAL_NO' : "6150SE 580-22-01",
  'YEAR_BUILT' : 1987,
  'PV_ORIENTATION' : "Vertical", # vertical or horizaontal
  'MATERIAL' : "SA 516 Gr. 70",
   
   # dimension
   'OD' : 105, # inch, Outside Dia
   'L' : 330, # inch length / height of vessel

  # DESIGN DATA
  'DP' : 300, # psig, design pressure
  'DT' : 250, # F, design temp
  'CA' : 0.0625, # inch, Corrosion Allowance
  'RT' : "FULL",     # RT during design: FULL, PARTIAL

  # SHELL DATA
  'S_SHELL' : 20000, # SA 516 Gr 70
  'E_SHELL' : 1,
  'T_NOM_SHELL' : 0.375, # inch

  # HEAD DATA
  'HEAD_TYPE' : "Ellipsoidal", # Ellipsoidal, Hemispherical, Torispherical, Flat
  'S_HEAD' : 20000, # SA 516 Gr 70
  'E_HEAD' : 1,
  'T_NOM_HEAD' : 0.375, # inch,
  
  # factor K for ellipsoidal head 2:1
  'K' : 1,

  ###################
  # INSPECTION DATA #
  ###################
  # most inspection data is in milimeters unit

  ### INSPECTION INTERVAL ###
  'INTERVAL': 4, # YEARS AS PER CERTIFICATION

  ### NOW  ### 
  'insp_date_now' : "7/01/2020", # 7 Jan 2020

  # SHELL
  't_nom_shell' : 9.525, # mm, nominal shell thick
  't_now_shell' : 7.35, # mm, min thick in shell from current inspection data

  # HEAD
  't_nom_head' : 11.5 , # mm, suggest to use max value of current inspection if actual thick > nominal thick
  'head1_name' : "TOP HEAD", # TOP / LEFT HEAD
  't_now_head1' : 10.38, # mm, min  top/left head thick of current inspection

  'head2_name' : "BOTTOM HEAD", # BOTTOM / RIGHT HEAD
  't_now_head2' : 11.07, # mm, min bottom/right head thick of current inspection

  ### PREVIOUS ###
  ## If data is not available, type  None for all field

  'insp_date_prev' : "7/01/2017", # date/month/year  7 Jan 2017, type None if not availble

  # SHELL
  't_prev_shell' : None, # mm, min thick shell of previous inspection data, or type None if not available

  # HEAD
  't_prev_head1' : 10.5, # mm, top / left head, type None if not available
  't_prev_head2' : 11.5, # mm,   bottom /right head, type None if not available

  ### NOZZLES ###
  'S_NOZZLE' : 20000, # psi
  'E_NOZZLE' : 1, 
  'nozzles_name' : [ "N1", "N2", "N3", "N4", "N12", "N13", "MH1", "MH2", "MH3" ],
  'nozzles_size' : [ 3, 4, 3 ,4, 4, 3, 26, 24, 26  ], # NPS in inch

  # inch, height of nozzle location measured from top
  'nozzles_height': [90, 0, 351, 145, 145, 265, 351, 90, 351 ], 

  # mm, nominal thick, mostly fabricated from shell plate,  
  # https://www.engineeringtoolbox.com/nominal-wall-thickness-pipe-d_1337.html
  'nozzles_thick_nom' : [9.525, 9.525, 9.525, 9.525, 9.525, 9.525, 9.525, 9.525, 9.525], 

  # mm, min thick current inspection
  'nozzles_thick_now' : [7.02, 9.90, 7.63, 8.85, 8.61, 8.74, 8.31, 9.92, 9.73], 

  # mm, min thick previous inspection or type None if not available e.q [None, None, None, None]
  'nozzles_thick_prev' : [7.1, 10, 8, 9, 9, 9, 9, 9, 9] 
}

# %%
DATA
# Out:
# {'NAME': 'Gauging Separator B',
#  'TAG_NO': '6105-E-580-22-01 / 353SW-ZV-01C',
#  'AREA': 'AWT 4 SW',
#  'SERIAL_NO': '6150SE 580-22-01',
#  'YEAR_BUILT': 1987,
#  'PV_ORIENTATION': 'Vertical',
#  'MATERIAL': 'SA 516 Gr. 70',
#  'OD': 105,
#  'L': 330,
#  'DP': 300,
#  'DT': 250,
#  'CA': 0.0625,
#  'RT': 'FULL',
#  'S_SHELL': 20000,
#  'E_SHELL': 1,
#  'T_NOM_SHELL': 0.375,
#  'HEAD_TYPE': 'Ellipsoidal',
#  'S_HEAD': 20000,
#  'E_HEAD': 1,
#  'T_NOM_HEAD': 0.375,
#  'K': 1,
#  'INTERVAL': 4,
#  'insp_date_now': '7/01/2020',
#  't_nom_shell': 9.525,
#  't_now_shell': 7.35,
#  't_nom_head': 11.5,
#  'head1_name': 'TOP HEAD',
#  't_now_head1': 10.38,
#  'head2_name': 'BOTTOM HEAD',
#  't_now_head2': 11.07,
#  'insp_date_prev': '7/01/2017',
#  't_prev_shell': None,
#  't_prev_head1': 10.5,
#  't_prev_head2': 11.5,
#  'S_NOZZLE': 20000,
#  'E_NOZZLE': 1,
#  'nozzles_name': ['N1', 'N2', 'N3', 'N4', 'N12', 'N13', 'MH1', 'MH2', 'MH3'],
#  'nozzles_size': [3, 4, 3, 4, 4, 3, 26, 24, 26],
#  'nozzles_height': [90, 0, 351, 145, 145, 265, 351, 90, 351],
#  'nozzles_thick_nom': [9.525,
#   9.525,
#   9.525,
#   9.525,
#   9.525,
#   9.525,
#   9.525,
#   9.525,
#   9.525],
#  'nozzles_thick_now': [7.02, 9.9, 7.63, 8.85, 8.61, 8.74, 8.31, 9.92, 9.73],
#  'nozzles_thick_prev': [7.1, 10, 8, 9, 9, 9, 9, 9, 9]}

# %%
ffs = FFS(DATA)
ffs.summary()
# Out:
#     ====================
#     INTEGRITY EVALUATION
#     ====================
#
#     NAME            = Gauging Separator B
#     TAG NO          = 6105-E-580-22-01 / 353SW-ZV-01C
#     AREA            = AWT 4 SW
#     ORIENTATION     = Vertical
#     HEAD TYPE       = Ellipsoidal
#     OUTSIDE DIA     = 105 inch
#     LENGTH          = 330 inch
#     DESIGN PRESSURE = 300 psig
#     DESIGN TEMP     = 250 F
#     YEAR BUILT      = 1987
#     INSPECTION DATE = 7/01/2020
#
#     ==SUMNMARY EVALUATION==
#
#         Section      RL     MAWP  is_Fit?
# 0         Shell    0.00   102.35    False
# 1      TOP HEAD    0.00   151.91    False
# 2   BOTTOM HEAD    0.00   149.84    False
# 3            N1   59.03  3366.29     True
# 4            N2  100.00  3792.75     True
# 5            N3   41.28  3487.45     True
# 6            N4  100.00  3326.77     True
# 7           N12   46.69  2980.31     True
# 8           N13   71.51  4223.82     True
# 9           MH1   13.69   391.88     True
# 10          MH2  100.00   650.91     True
# 11          MH3  100.00   589.33     True
#
#     ----------------
#     SECTION - SHELL
#     ----------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0659 mm/year
#       - Short Term Corrosion Rate = None mm/year
#       - Selected Corrosion Rate is 0.0659 mm/year
#
#       *Thickness*
#       - Thickness actual = 7.35 mm.
#       - Thickness Required = 19.8832 mm.
#
#       *Integrity*
#       - Remaining life = 0 years.
#       - MAWP @next inspection at interval 4 years = 102.35
#
#       *Conclusion*
#
#       The Shell of the Vessel is NOT fit for service with 4 years interval at next inspection in 07-Jan-2024
#       The MAWP is 102.35 psig which is lower than design pressure (300 psig).
#
#       Recommeds to shorten next inspection interval, perform repair or derating.
#
#       Below is the projection derating pressure and remaining life date.
#
#       Derating pressure should be selected as appropriate.
#
#           DERATING PRESSURE VS REMAINING LIFE
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           |  Pressure(psig) |   RL Date      |   Next Insp. Date
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           | 300              |   07-Jan-2020  |   07-Jan-2020    |
#           | 299              |   07-Jan-2020  |   07-Jan-2020    |
#           | 298              |   07-Jan-2020  |   07-Jan-2020    |
#           | 297              |   07-Jan-2020  |   07-Jan-2020    |
#           | 296              |   07-Jan-2020  |   07-Jan-2020    |
#           | 295              |   07-Jan-2020  |   07-Jan-2020    |
#           | 294              |   07-Jan-2020  |   07-Jan-2020    |
#           | 293              |   07-Jan-2020  |   07-Jan-2020    |
#           | 292              |   07-Jan-2020  |   07-Jan-2020    |
#           | 291              |   07-Jan-2020  |   07-Jan-2020    |
#           | 290              |   07-Jan-2020  |   07-Jan-2020    |
#           | 289              |   07-Jan-2020  |   07-Jan-2020    |
#           | 288              |   07-Jan-2020  |   07-Jan-2020    |
#           | 287              |   07-Jan-2020  |   07-Jan-2020    |
#           | 286              |   07-Jan-2020  |   07-Jan-2020    |
#           | 285              |   07-Jan-2020  |   07-Jan-2020    |
#           | 284              |   07-Jan-2020  |   07-Jan-2020    |
#           | 283              |   07-Jan-2020  |   07-Jan-2020    |
#           | 282              |   07-Jan-2020  |   07-Jan-2020    |
#           | 281              |   07-Jan-2020  |   07-Jan-2020    |
#          ---------------------------------------------------------
#
#     --------------------------
#     SECTION - HEAD 1 TOP HEAD
#     --------------------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0339 mm/year
#       - Short Term Corrosion Rate = 0.04 mm/year
#       - Selected Corrosion Rate is 0.04 mm/year
#
#       *Thickness*
#       - Thickness actual = 10.38 mm.
#       - Thickness Required = 19.8832 mm.
#
#       *Integrity*
#       - Remaining life = 0 years.
#       - MAWP @next inspection at interval 4 years = 151.91
#
#       *Conclusion*
#
#       The TOP HEAD of the Vessel is NOT fit for service with 4 years interval at next inspection in 07-Jan-2024
#       The MAWP is 151.91 psig which is lower than design pressure (300 psig).
#
#       Recommeds to shorten next inspection interval, perform repair or derating.
#
#       Below is the projection derating pressure and remaining life date.
#
#       Derating pressure should be selected as appropriate.
#
#           DERATING PRESSURE VS REMAINING LIFE
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           |  Pressure(psig) |   RL Date      |   Next Insp. Date
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           | 300              |   07-Jan-2020  |   07-Jan-2020    |
#           | 299              |   07-Jan-2020  |   07-Jan-2020    |
#           | 298              |   07-Jan-2020  |   07-Jan-2020    |
#           | 297              |   07-Jan-2020  |   07-Jan-2020    |
#           | 296              |   07-Jan-2020  |   07-Jan-2020    |
#           | 295              |   07-Jan-2020  |   07-Jan-2020    |
#           | 294              |   07-Jan-2020  |   07-Jan-2020    |
#           | 293              |   07-Jan-2020  |   07-Jan-2020    |
#           | 292              |   07-Jan-2020  |   07-Jan-2020    |
#           | 291              |   07-Jan-2020  |   07-Jan-2020    |
#           | 290              |   07-Jan-2020  |   07-Jan-2020    |
#           | 289              |   07-Jan-2020  |   07-Jan-2020    |
#           | 288              |   07-Jan-2020  |   07-Jan-2020    |
#           | 287              |   07-Jan-2020  |   07-Jan-2020    |
#           | 286              |   07-Jan-2020  |   07-Jan-2020    |
#           | 285              |   07-Jan-2020  |   07-Jan-2020    |
#           | 284              |   07-Jan-2020  |   07-Jan-2020    |
#           | 283              |   07-Jan-2020  |   07-Jan-2020    |
#           | 282              |   07-Jan-2020  |   07-Jan-2020    |
#           | 281              |   07-Jan-2020  |   07-Jan-2020    |
#          ---------------------------------------------------------
#
#     ------------------------------
#     SECTION - HEAD 2 BOTTOM HEAD
#     ------------------------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.013 mm/year
#       - Short Term Corrosion Rate = 0.1433 mm/year
#       - Selected Corrosion Rate is 0.1433 mm/year
#
#       *Thickness*
#       - Thickness actual = 11.07 mm.
#       - Thickness Required = 20.6672 mm.
#
#       *Integrity*
#       - Remaining life = 0 years.
#       - MAWP @next inspection at interval 4 years = 149.84
#
#       *Conclusion*
#
#       The BOTTOM HEAD of the Vessel is NOT fit for service with 4 years interval at next inspection in 07-Jan-2024
#       The MAWP is 149.84 psig which is lower than design pressure (300 psig).
#
#       Recommeds to shorten next inspection interval, perform repair or derating.
#
#       Below is the projection derating pressure and remaining life date.
#
#       Derating pressure should be selected as appropriate.
#
#           DERATING PRESSURE VS REMAINING LIFE
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           |  Pressure(psig) |   RL Date      |   Next Insp. Date
#          +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           | 300              |   07-Jan-2020  |   07-Jan-2020    |
#           | 299              |   07-Jan-2020  |   07-Jan-2020    |
#           | 298              |   07-Jan-2020  |   07-Jan-2020    |
#           | 297              |   07-Jan-2020  |   07-Jan-2020    |
#           | 296              |   07-Jan-2020  |   07-Jan-2020    |
#           | 295              |   07-Jan-2020  |   07-Jan-2020    |
#           | 294              |   07-Jan-2020  |   07-Jan-2020    |
#           | 293              |   07-Jan-2020  |   07-Jan-2020    |
#           | 292              |   07-Jan-2020  |   07-Jan-2020    |
#           | 291              |   07-Jan-2020  |   07-Jan-2020    |
#           | 290              |   07-Jan-2020  |   07-Jan-2020    |
#           | 289              |   07-Jan-2020  |   07-Jan-2020    |
#           | 288              |   07-Jan-2020  |   07-Jan-2020    |
#           | 287              |   07-Jan-2020  |   07-Jan-2020    |
#           | 286              |   07-Jan-2020  |   07-Jan-2020    |
#           | 285              |   07-Jan-2020  |   07-Jan-2020    |
#           | 284              |   07-Jan-2020  |   07-Jan-2020    |
#           | 283              |   07-Jan-2020  |   07-Jan-2020    |
#           | 282              |   07-Jan-2020  |   07-Jan-2020    |
#           | 281              |   07-Jan-2020  |   07-Jan-2020    |
#          ---------------------------------------------------------
#
#       -------------
#       NOZZLE - N1
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0759 mm/year
#       - Short Term Corrosion Rate = 0.0267 mm/year
#       - Selected Corrosion Rate is 0.0759 mm/year
#
#       *Thickness*
#       - Thickness actual = 7.02 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 59.03 years.
#       - MAWP @next inspection at interval 4 years = 3366.29
#
#       *Conclusion*
#
#       The N1 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 3366.29 psig which is larger than design pressure (300 psig).
#       The remaining life is 59.03 years which is due in 17-Jan-2079.
#
#
#       -------------
#       NOZZLE - N2
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 1e-05 mm/year
#       - Short Term Corrosion Rate = 0.0333 mm/year
#       - Selected Corrosion Rate is 0.0333 mm/year
#
#       *Thickness*
#       - Thickness actual = 9.9 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 3792.75
#
#       *Conclusion*
#
#       The N2 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 3792.75 psig which is larger than design pressure (300 psig).
#       The remaining life is 100 years which is due in 08-Jan-2120.
#
#
#       -------------
#       NOZZLE - N3
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0574 mm/year
#       - Short Term Corrosion Rate = 0.1233 mm/year
#       - Selected Corrosion Rate is 0.1233 mm/year
#
#       *Thickness*
#       - Thickness actual = 7.63 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 41.28 years.
#       - MAWP @next inspection at interval 4 years = 3487.45
#
#       *Conclusion*
#
#       The N3 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 3487.45 psig which is larger than design pressure (300 psig).
#       The remaining life is 41.28 years which is due in 18-Apr-2061.
#
#
#       -------------
#       NOZZLE - N4
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0205 mm/year
#       - Short Term Corrosion Rate = 0.05 mm/year
#       - Selected Corrosion Rate is 0.05 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.85 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 3326.77
#
#       *Conclusion*
#
#       The N4 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 3326.77 psig which is larger than design pressure (300 psig).
#       The remaining life is 100 years which is due in 08-Jan-2120.
#
#
#       -------------
#       NOZZLE - N12
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0277 mm/year
#       - Short Term Corrosion Rate = 0.13 mm/year
#       - Selected Corrosion Rate is 0.13 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.61 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 46.69 years.
#       - MAWP @next inspection at interval 4 years = 2980.31
#
#       *Conclusion*
#
#       The N12 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 2980.31 psig which is larger than design pressure (300 psig).
#       The remaining life is 46.69 years which is due in 15-Sep-2066.
#
#
#       -------------
#       NOZZLE - N13
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0238 mm/year
#       - Short Term Corrosion Rate = 0.0867 mm/year
#       - Selected Corrosion Rate is 0.0867 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.74 mm.
#       - Thickness Required = 2.54 mm.
#
#       *Integrity*
#       - Remaining life = 71.51 years.
#       - MAWP @next inspection at interval 4 years = 4223.82
#
#       *Conclusion*
#
#       The N13 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 4223.82 psig which is larger than design pressure (300 psig).
#       The remaining life is 71.51 years which is due in 12-Jul-2091.
#
#
#       -------------
#       NOZZLE - MH1
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 0.0368 mm/year
#       - Short Term Corrosion Rate = 0.23 mm/year
#       - Selected Corrosion Rate is 0.23 mm/year
#
#       *Thickness*
#       - Thickness actual = 8.31 mm.
#       - Thickness Required = 5.162 mm.
#
#       *Integrity*
#       - Remaining life = 13.69 years.
#       - MAWP @next inspection at interval 4 years = 391.88
#
#       *Conclusion*
#
#       The MH1 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 391.88 psig which is larger than design pressure (300 psig).
#       The remaining life is 13.69 years which is due in 15-Sep-2033.
#
#
#       -------------
#       NOZZLE - MH2
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 1e-05 mm/year
#       - Short Term Corrosion Rate = 1e-05 mm/year
#       - Selected Corrosion Rate is 1e-05 mm/year
#
#       *Thickness*
#       - Thickness actual = 9.92 mm.
#       - Thickness Required = 4.6215 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 650.91
#
#       *Conclusion*
#
#       The MH2 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 650.91 psig which is larger than design pressure (300 psig).
#       The remaining life is 100 years which is due in 08-Jan-2120.
#
#
#       -------------
#       NOZZLE - MH3
#       -------------
#
#       *Corrosion rate*
#       - Long Term Corrosion Rate = 1e-05 mm/year
#       - Short Term Corrosion Rate = 1e-05 mm/year
#       - Selected Corrosion Rate is 1e-05 mm/year
#
#       *Thickness*
#       - Thickness actual = 9.73 mm.
#       - Thickness Required = 5.162 mm.
#
#       *Integrity*
#       - Remaining life = 100 years.
#       - MAWP @next inspection at interval 4 years = 589.33
#
#       *Conclusion*
#
#       The MH3 of the Vessel if fit for service with 4 years interval at next inspection date in 07-Jan-2024.
#       The MAWP is 589.33 psig which is larger than design pressure (300 psig).
#       The remaining life is 100 years which is due in 08-Jan-2120.
